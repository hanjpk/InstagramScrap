# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

post_link = input('masukkan link postingan, setelah ini silakan login')

browser = webdriver.Chrome(r"D:\P\Phyton\chromedriver.exe")
browser.get(post_link)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_33048\3678882822.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(r"D:\P\Phyton\chromedriver.exe")

# %%
from selenium.webdriver.support.ui import WebDriverWait
wait = WebDriverWait(browser, 30)
from selenium.webdriver.support import expected_conditions as EC
jml_like = input('masukkan jumlah like...')

browser.get(post_link+'liked_by/')

SCROLL_PAUSE_TIME = 0.5

sleep (5)

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
id_like = input('masukkan XPATH...')
for i in range(1,int(jml_like)+1):
    strs = '//*[@id='
    strs3 = ']/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div[1]/div/div['
    strs2 = ']/div[2]'
    blocks = browser.find_element(By.XPATH, strs + id_like + strs3 + str(i) + strs2).text
    print (blocks)
# Out:
# arinta_mpus
# Arinta
# nadirathiodoris_
# Dira
# hafidz_app
# Hafidz Alamsyah Putra
# dea.aulia._
# 1%
# rusmaja_madhan
# روسماجا مضان
# qosina_sadiyah
# qosinatus sa'diyah
# hra_5_
# Shemmy bukan Sammy
# ilhamsidiq_
# ilham abdullah sidiq
# liangberto
# Liang Berto
# yulianti.sikumbang
# Yulianti Sikumbang
# andhikaapratama_
# gita_panggalaha
# Gita_Panggalaha
# nadia.chandra
# Nadia Chandra
# novyanto_s
# 𝙽𝙾𝚅𝚈𝙰𝙽𝚃𝙾 𝚂𝙰𝙿𝚄𝚃𝚁𝙰
# mrizalkp
# Mochamad Rizal
# nuralidade
# Ade Nuralida
# sarinah.rinah.336
# Sarinah Rinah
# shollauli
# hendriksetyono62
# Hendrik S
# saidunnn25_
# Saida
# dewisetianiii
# sky_dam_daam19
# Dam Daam
# antomaulidi_17
# Maulidianto
# rzy_sknju
# M.Rizky Anugrah
# afnaafazh_
# Afnaa Fauziah
# yeshanov_
# yesha kn
# argo_kusuma_
# Argo Kusuma
# dhimazfix
# DhimazFitico
# lilahlzh_
# Lila Halizah
# sausynf__
# 2nd
# maulina.dinda
# helmi._.fuadi
# Helmi Fuadi
# umilestari1231
# umi lestari
# acengs18
# 셜리 라피샤 사리
# erul_mln
# 𝙆𝙝𝙖𝙞𝙧𝙪𝙡 𝙐𝙢𝙖𝙢 イスナリ
# tasyarenii
# Tasya
# comel_jmbo
# comel kecil
# sonson0550
# Soni Lah
# nayllaaab
# Nayla Bilqis faiha
# novelgiov
# Novella Giovanna
# muhammadfajaralgibran
# MuhammadFajarAlgibran
# maiyulasri
# Maiyulasri
# andrrwhyd
# kadek andri d
# shaliyahhhhh
# Salwa Hasna Aliyah
# _lailafatima
# Laila Fatima
# hildacahya_
# Hilda Cahya Yolanda
# afifahht_
# 𝓗𝓪𝓽𝓮
# alrahmatya
# andrepandiangan_
# Andre Yoel Pandiangan
# why.dhan
# Rakhmat 'D' Ramdhanu
# kebunmemori09
# Andri Ansyah
# novisilvianitaaaa
# putrrienne_
# po🐣
# angga.hadiwinata11
# Angga Hadiwinata
# xaves_adt
# Fery Aditya
# sahetapyvera
# VERA.
# julfiandimanungkalit92
# Julfiandi
# achmed_gerland
# Achmed Gerland
# dwinvtss_
# V i t a k
# _rohayah77
# ⓐⓨⓐ
# rosa_rsdaaa
# occaaa
# khazikovoy
# Hayo.tebak ♍
# _tyrhm
# anggtnfl
# liviaaurelliaa
# 문별일
# gifari_deldi
# Gifari Fauzil Deldi
# namirazulaikha
# Namira Zulaikha
# chairanihanny
# hanny chairani05
# jagadunya
# Jagaduny@
# _hdaa1
# Huda Wahyujati
# mariskadwitaningrum
# Mdn
# syaputra_bkl
# Milcka syaputra
# akmalarireal
# Akmal Ari Putra
# binarhaafizh
# Binar Haafizh
# farahlimai
# Farahli Mai
# ridhar92
# Ridha92
# farhan.nul.hakim
# Farhan Nul hakim
# lintangjaem13
# xyzxJae_min
# ilhamsptr___
# Ilham Saputra
# nafisahselma
# Nafisah Selma Yunia
# ngrhaa22
# Kang Cilok
# chairunnisa.cakes
# Chairunnisa
# fbyan__
# widyaayunitbn
# Widya Ayuni Tambunan
# andiihaeril28
# Andi Haeril
# pxstrymoon
# 〝2acc◌̊ ̖́
# aa.sabana
# kezia.priyananda
# aisyahismah04
# ✨🌻🦋
# nfh_fziah
# ʜᴀɴɪғᴀʜ ғᴀᴜᴢɪᴀʜ ᴋʜᴀɪʀᴀ
# aurora_nuda_firnas_widodo
# Anton Widodo
# beritalabuanbajo
# Berita Labuan Bajo
# maya_sari1184
# maya sari
# noviya_hanafi
# Noviyanti Hanafi
# alungvenus31
# _putriwardhani
# ifauziah637
# Isna Fauziah
# desikur95
# Desy Kurnia
# fangii_0926
# Fangii
# lucianopauluz
# Ano
# kesiea_indah
# Call me (kesi)ea!
# morich_tiga8
# MorGan ZaDox
# frensiskaputri_
# Frensiska Putri
# wahyukamukitaa_
# Wahyuu
# serlilabia97
# Serlianti
# de_ndi28
# Hamba Allah
# frmann__17
# ndikk
# wahyu_aleef
# Wahyu Farid Alifianto
# hirraaa12
# dwiira
# daniyantiiiii
# ekadwiana_022
# Eka Dwiana Riri Todingan
# juann_xyz
# Juan Idhar Jannata
# aszun97
# Asep Zuna
# vividpr_
# Vivi Dian Pratiwi
# abelnov_18
# Abeliya Novsanti
# srwulndri
# iniwulanoke
# febrikaintan
# adamsutrisno23
# Adam Sutrisno
# s.nurrhasanah
# mei_sdiantama
# Mei Oyeeh Fishy
# m.iqbalsalman
# Muhammad Iqbal Salman
# setyabudi412
# setyabudi412
# kukuhantonius
# Antonius Kukuh Prasetyaji
# agung_leonardy
# A.P
# liaa_apriliaani
# riyatiru
# Riyati
# ardy_willy
# willy ardiyanto
# m.i.wijayanto
# 𝑀𝓊𝒽𝒶𝓂𝓂𝒶𝒹 𝐼𝓁𝒽𝒶𝓂 𝒲𝒾𝒿𝒶𝓎𝒶𝓃𝓉𝑜
# muchtar_tahir
# Muchtar
# marietta_purbaa
# 𝓕𝓵𝓸𝓻𝓮𝓷𝓽𝓲𝓷𝓪
# vanesa.putriana
# vanesa putriana
# faaaannisa
# erfa k
# derysepti
# deryseptiawanardi
# heyntan_
# iniintan🦋
# fslrhmn_11
# мυнαммα∂ ƒαιѕαℓ яσнмαη
# aaa.dddiitt
# ajeng_adnda
# Ajeng Adinda Putri
# ravirj16
# Ravi
# f.putri.s_
# Putri
# putrayerikho_
# Yerikho Putra P. †
# dayu66341
# dian ayu
# angelarossa_1260
# Angela R
# trinit_intanf4
# Trinita_IntanF4,S.KM
# alfaa_nataris
# lukmaanhakim71
# lukman hakim
# rayhanbagusfebrianto
# RayhanBagus
# alraffliansyach
# al
# nurhhlimah
# sri_scorpio_girl
# Sri Astutik
# ramadonikhirtin
# Ramadoni Khirtin
# sylvesterada_
# Sylvester Aaron
# adrian.renaldi.r
# Adrian Renaldi
# khasan_aluwi
# Khasan Bin Tamrin
# afrin_8.9
# @Afrin_89
# ermasr01
# Syafa Azzulfa
# etsujona_
# Slf_Anna
# agurel.__
# nia
# jesendadefretes
# Keep It High
# _rizkisyhp
# lalalala
# cheelciagbr
# cheelciagbr
# putrajasmanputrajasman
# Putra Jasman
# irene_serly_batsira
# Irene_Serly_Batsira
# aji.ast_
# Novri Dwi Astriaji
# putripuspsr
# 𝒫𝓊𝓉𝓇𝒾 𝒫𝓊𝓈𝓅𝒶𝓈𝒶𝓇𝒾✨
# 4.r15_
# Yohanes Arisofianto
# tak.pernah.ternilai_
# Adzim Na'afinudien
# farrasgio
# Farrasgio Yogantara
# apr_linaaa
# APRILINA
# zeynn_31
# Sam
# pratama_nur_andriantoo
# arjun_rey10
# Arjuna Reynaldi
# rizkynamm
# Rizky Khoirul A
# vonnysylvana
# Vonny Sylvana
# citraaln
# citra
# revalisaaa_
# Revalisa
# teguhls
# guh
# hyacinta_astuti
# Hyacinta Astuti
# teddy_tribudiyanto
# 𝓣𝓮𝓭𝓭𝔂 𝓴𝓮𝓻𝓽𝓪𝓻𝓪𝓭𝓳𝓱𝓪𝓼𝓪
# htengkurahmat
# tengku rahmat hidayat
# haru_elfs
# Ananda Ayu
# nyosiii_
# virdarizky
# Rizky Virda
# ariepitoy
# arie pitoy
# karina_13z
# loennaa_612
# yoni_ghs
# j
# patmawatikrishnap
# Patmawatikrishna
# nindyynva
# nindii novianaaa
# basrul_hutabarat
# Bang Basrul
# smackmaesz
# naanatttt_
# 𝓷𝓪𝓽𝓪𝓼𝔂𝓪𝓪
# exnword
# sephiaa.s_
# Sephia Sulastri
# minfattt
# fatim
# m_hariss75
# Muhammad Haris Syaifullah
# fikrialrasyid_27
# Muhammad Fikri Al Rasyid Harya Wiryawan
# mandebtrcookies
# Ⓜ️an
# rudytazar70
# Rudy Kurniawan
# haidaramrurusdan
# Haidar Amru Rusdan
# 1caelannn9_
# •~Ⓒⓐⓔⓛⓐⓝ~•
# mfatkhu.rizqi
# M Fatkhu Rizqi
# yygg_348
# Akhmad Yoga
# bkaziamashel
# kazia mashel belvania
# puri_mastiara
# Puri Mastiara
# bldmoonnn
# kandaga1933
# D a g a
# widiyawan_
# ᴡɪᴅɪʏᴀᴡᴀɴ
# kautsarachmad24
# Achmad Muhammad Al Kautsar
# jordanachlw
# JordanC
# novinitailus
# Novi_Nitailus
# chrisyepapilaya
# CCIP
# tembaga2sulfat
# Annas
# amril19_
# AmriL
# albhilaselbhara
# jep.saputra
# Yepri Saputra
# nailifd
# Naili F.
# ahmad_alfarisihaslan1998
# Ahmad Alfarisi Haslan
# bntngkysalp
# binȶꪖꪀᧁ
# mhmmdambia
# bih
# yantie591
# Ozzy_Yanthie
# rindaaa_m
# Rinda
# marianawaridjo
# Mariana Waridjo
# sofieubba
# Sofieubba
# rafaist
# Rafa Zafirah Istiqomah
# bimatallah96
# Muhammad Syauqi Bima A
# putriramadani26_
# byyunbbe
# attalaprayoga
# only thinking about 505
# liynasr
# Ngainul Ngaliyah
# ssy.anwar06
# Muhammad Syaiful Anwar ~
# adi.saptrraa
# Adi
# km_fdhl
# Fadhillah Ahmad
# thankyousalsaa_
# Salsabil Shafa
# rokhim8687
# Nur Rokhim
# yourjune23
# imyourjune✨
# niaoctora_olshop
# Nia Octora OLShop
# yolanda_s_rumahorbo
# YSR
# mrmhdrfli
# 𝓜𝓾𝓱𝓪𝓶𝓶𝓪𝓭𝓡𝓪𝓯𝓵𝓲
# afterexplore
# napitasupangkat
# PANGKAT
# annisa_hftri
# Annisa Hafitri
# ovovava
# Ova
# niayusniawt_
# intan_rahmawati567
# tan
# indah.srdw
# 👑 Indah Sari Dewi 👑
# r_fadlyr
# Radhithe Fadly Ramdani
# lasievaaa
# ✨🌈
# iqbaludin_17
# Muhamad_iqbal
# robbyaguung
# ʀᴏʙʙʏ ᴀɢᴜɴɢ ᴀʟ ꜰᴀᴊʀɪ
# msrlfajarntby_
# Fajar Muhammad Runtuboy
# rosianandhi
# ℝ𝕠𝕤𝕚𝕒𝕟𝕒 𝔸𝕟𝕕𝕙𝕚𝕜𝕒𝕤𝕒𝕣𝕚 👩🏻‍🏫
# arietaeka
# A
# fikri_ramadhan96
# 𝓕𝓲𝓴𝓻𝓲 𝓒𝓱𝓲𝓲𝓮
# kim.yasada
# Kimya
# merysofyaa
# Anggi
# alpin_ghc
# alpin_botutihe
# ikaanurasiyah
# 𝐈𝐤𝐚
# bototheco_
# Ridho Pratama
# shofihmidah
# yoon.daktahu
# widyasartika31
# ωι∂уα 'ωιωι∂' ѕαятιкα
# brianzz_996
# -
# ofana_tw
# Ofana Tri Wibowo
# indahfridayantii
# 🐰💚
# mptr928
# M Putra Ainun Na'im
# adindaaa_.ah
# adinda hasna
# kharisma_pandu
# Pandu Kharisma Sari
# muhmmd_spt
# M Septa
# habiinr
# Hiba Nurdwi I
# alam.ricaksono
# ADE LAMBANG R.
# iam_heksiana
# septiheksiana
# ekaaimania
# 𝓔
# budi1508
# Budi Han
# onytekakk
# 🅐🅡🅡🅐🅗🅜🅐🅝
# deanurhalisa3
# DeaNurhalisa
# fir.yal
# Firyal
# aji_p33
# Aji Prasetiyo
# amessuu
# anonimus
# nurmutmainahh_
# N a メ
# tu_aditzz
# ɪ ᴘᴜᴛᴜ ᴀᴅɪᴛ ᴊᴀʏᴀ ʀᴀᴅɪᴛʏᴀ
# novia_lllr
# Novialllrmdhni
# luthfiazmi_002
# Muhammad Luthfi Azmi
# sagitard1200
# Sagita Ramadhanti
# abottgentania
# Abott 🐾🐶🐕
# vickysaputra_vs26
# vicuy_vs
# ibnxnzr
# ιвηυ ηαzαя
# robyjumbo
# Roby Jumbo
# muhammad.adriansyahhh
# Muhammad Adriansyah
# ardhanighiffa
# ahmadaji7906
# Ahmad Aji Pangestu
# fauzan.ghozii
# Fauzan Ghozi Imani
# brliantap_
# BerlianTap
# spsuinjktofficial
# Pascasarjana UIN Jakarta
# munira_nira
# munira
# ini_juniiiiiii
# juniiiiiiiiiiiiiiiiiii
# fardhannaim
# M Fardhan N
# ernha_w07feb95
# Nha ERna W
# trianto.harry
# Harry Lesmana
# dzk.amri_
# zakii
# oldschool4950
# oldschool
# divahidayatika_
# yourbby🍷
# dnannisautami
# nangkobis
# nanggkobis
# rafmy_
# rafika tri💜
# _ainii.s
# aii
# rotua_simorangkir
# rotuasimorangkir
# fairuzmalang12
# 𝐅𝐚𝐢𝐫𝐮𝐳 𝐒𝐚𝐤𝐡𝐚 𝐙𝐮𝐛𝐚𝐲𝐫
# sitiwardah.23
# 🐙
# ghipariyyrifqii__
# GHIFARY RIFQI LAUDZA
# tejowirakusuma11
# 𝓣𝓮𝓳𝓸 𝓦𝓲𝓻𝓪 𝓚𝓾𝓼𝓾𝓶𝓪
# miyaaa_69
# Miyaaa_
# dewiap248
# Dewi Pratiwi
# _mhammadardiansyah
# Muhammad Ardiansyah
# sindy_amirr
# iinn
# malna_28
# Muhammad Malna
# albert_saputra.10
# Albert10
# gracetobtng
# 𝘎𝘳𝘦𝘴𝘵𝘰
# adhitya_windu
# Adhitya Windu Prajito
# kessy_cherio
# Kessy
# jihanamira11
# apsbllaaa_
# اديانى فوترى سلسبيلا
# suprayiant
# rulhuda_
# Khoirul Huda
# asihcitaresmi
# Asih Chitaresmi
# _21muhammadhs
# Maometto 하피드 سيفلي
# prlyxzyh
# xyzcba
# noviyantidyaha
# Noviyanti dyah a
# margaretaajeng
# Margareta Ajeng 🎀
# rino_jst019
# RINO JASTIAN_
# _.iiiaaaaaannnnnn
# ian
# mairadrmaputri
# Maii
# hendra_s_juara_10
# Yusuf Hendra
# ae_yunaster
# AyuNa_Yun
# r.anwarrr
# Muhamad Rafii
# divabalqis_c.k
# divabalqiscandrakirana
# moch_febri_putra12
# Moch Febri Putra
# madanahh
# adana
# k___rn
# golunt
# ridwandwi_ramdan
# Ridwan Dwi Ramdan
# shln_yn4
# 𝓢𝓱𝓪𝓵𝓲𝓷𝓪 𝓨𝓾𝓵𝓲𝓷𝓪𝓻 𝓝.
# sand_amanik2510
# 𝓖𝓮𝓫𝔂 𝓢𝓪𝓷𝓭𝓪𝓶𝓪𝓷𝓲𝓴 ♡†
# shiskaikhaariyanti
# Shiska Ikha Ariyanti
# chickenoodle3_
# Zaaaaa!!!🍜
# r4tchy_
# pradnyaparameswara
# Docik
# inaaina_14
# Ina_Aina
# fatimahmuhammadatsigah
# Fatimah Muhammad Atsigah
# itayarus
# Ita Yarus
# wzeelas_
# nap
# yudhanov_911
# Yaduyyy
# stywn48_
# ぷんきせちあわぬ
# dimas_per.mana
# Dimas Permana
# nurfaizahjiza
# Jiza Nurfaizah
# cirebonbmpskota
# BMPS KOTA CIREBON
# iavicenna
# Ikrima Avicenna
# jossiatie
# Josie
# lyptr_i
# lyly
# nairaamnd
# ˗ˏˋ꒰ nai ꒱ *ੈ✩‧₊˚
# rahmanabdlh
# 𝐑𝐡𝐦𝐧.
# sky.mmu
# 아티야
# dwi_alfian77
# d_alfian
# lailynurulisnaini
# inggagarini
# Ingga
# indaaaggh
# I ♡
# shasitanzw_a
# hcxxvrm
# angkyloupatty_
# AWAS KRIBO
# jijuzfaturiu
# 𝕁𝕚𝕛𝕦𝕤𝕗𝕒𝕥𝕦𝕣𝕚𝕦
# ikadektisna
# TISNA
# hafidzarr_
# Hanifullah Hafidz Arrizal
# ekaseptiani398
# Eka Septiani
# n_done05
# Naial Salsabial
# aanggraini610_
# anggraini
# nor.halimah.7509
# Nor Halimah
# juandasitorus999
# juanda sitorus
# farisazhnt
# Farisa
# m.alfa003
# Alfa
# marcelinomoses_2002
# Moses Marcelino
# gideon_21_____
# 😇 😀 Nainggolan Hutabalian ~
# nadyadatuadam_
# Fdynrchynidatuadam
# itsme_vxkx
# Vika Nuralliya Ananda Arnurzen
# esty_hardianc.08
# Esty Hardian C
# miwaa.tann_
# B҉e҉l҉l҉e҉ 👀
# izaazafif
# Afif Izaaz
# ariswidiantoro_
# 𝐫𝐢𝐳𝐳
# salman.monoarfaaa
# J E R Y⚽
