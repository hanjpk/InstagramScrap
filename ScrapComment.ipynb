# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

post_link = input('masukkan link postingan, setelah ini silakan login')

browser = webdriver.Chrome(r"D:\P\Phyton\chromedriver.exe")
browser.get(post_link+'liked_by/')
sleep(4)
browser.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('akunnyobademo')
browser.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys('Pandak2018')
sleep(2)
browser.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[3]/button').click()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_26164\482959214.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(r"D:\P\Phyton\chromedriver.exe")

# %%
browser.get(post_link)
id_com = input('masukkan XPATH...')
while True:
    try:
        strr1 = '//*[@id='
        strr2 = ']/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div[1]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/li/div'

        browser.find_element(By.XPATH, strr1 + id_com + strr2).click()
        
    except:
        break

# %%
from msilib.schema import Error


for j in range(1,1000):
    str1 = '//*[@id='
    str2 = ']/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div[1]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/ul['
    str3 = ']/div/li/div/div/div[2]/h3/div/span/a'
    
    comment_u = browser.find_element(By.XPATH, str1 + id_com + str2 + str(j) + str3).text
    print(comment_u)
# Out:
# yahyaariefn
# febri_an12
# rafaist
# mabelyn.w
# deviarumbita
# gloryraa
# alrahmatya
# achmed_gerland
# fikrialrasyid_27
# _rizkisyhp
# irfanimamuddin
# nindyaaa.sa
# ariswidiantoro_
# ofana_tw
# maulanamalik_24
# intanfauziahhh
# adedoigai
# fareltempo
# dion.a_p
# arrrrsu
# izaazafif
# rokhim8687
# kurniawaneptr
# yolanda_s_rumahorbo
# ezafareza__
# hasyidagha_
# imawanmashuri_
# aureliamanabung_
# zul.fkr
# adeellaaaaa
# raihanhdhyy
# ahnafhs____
# faaaannisa
# muh.fauzulakbar
# ariesaditya217
# nurulimelia
# nurulimelia
# inggagarini
# tembaga2sulfat
# sunxxshak
# mnafmhr
# andrrwhyd
# jordanachlw
# pramuditoo__
# hanjpk
# daffandhikaa
# gabriel_parera
# ovovava
# naufalkf85
# novmukti
# shollauli
# nbiilkh
# avin.un
# leslykdwr_
# rafly.prtama
# leslykdwr_
# taufik_sinuraya
# dimas_per.mana
# putripuspsr
# anandamf_4
# rahmanabdlh
# arjun_rey10
# ramadonikhirtin
# juandasitorus999
# ilhamsidiq_
# akhdnraff
# andrewmatippanna___
# mdaim_wbs
# mdaim_wbs
# alfaa_nataris
# fadhliaslamaa_
# filbertm_
# fenura1303
# saya.nanda
# arinta_mpus
# nisnisa.kh
# yohanavioleta
# indraz03
# adrian.renaldi.r
# rizkahanaf
# irgiasf_
# isnainianjelinar
# ilham_zlkr
# faiqadit
# jp_christofel
# may_uani
# mzaacky_
# alifyulian7
# wahyu_aleef
# antomaulidi_17
# dewisetianiii
# ardian_sulthan
# luthfiazmi_002
# haidaramrurusdan
# ariesaditya217
# ariesaditya217
# ariesaditya217
# ariesaditya217
# ariesaditya217
# marcel_k18
# thx.sht
# dhito.axl77
# zaifal_m
# rafiff.01
# rahma_suseno
# elostmrg
# dzulfipratama
# fattahajala
# faiz_h_k
# shelyatr_
# rafly.prtama
# azizrwn_
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# d:\P\Phyton\test_comment.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/P/Phyton/test_comment.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> str2 = ']/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div[1]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/ul['
#       <a href='vscode-notebook-cell:/d%3A/P/Phyton/test_comment.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> str3 = ']/div/li/div/div/div[2]/h3/div/span/a'
# ----> <a href='vscode-notebook-cell:/d%3A/P/Phyton/test_comment.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> comment_u = browser.find_element(By.XPATH, str1 + id_com + str2 + str(j) + str3).text
#      <a href='vscode-notebook-cell:/d%3A/P/Phyton/test_comment.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> print(comment_u)
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mount_0_0_r6"]/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div[1]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/ul[113]/div/li/div/div/div[2]/h3/div/span/a"}
#   (Session info: chrome=105.0.5195.52)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B478B3+2193587]
# 	Ordinal0 [0x00AE0681+1771137]
# 	Ordinal0 [0x009F41A8+803240]
# 	Ordinal0 [0x00A224A0+992416]
# 	Ordinal0 [0x00A2273B+993083]
# 	Ordinal0 [0x00A4F7C2+1177538]
# 	Ordinal0 [0x00A3D7F4+1103860]
# 	Ordinal0 [0x00A4DAE2+1170146]
# 	Ordinal0 [0x00A3D5C6+1103302]
# 	Ordinal0 [0x00A177E0+948192]
# 	Ordinal0 [0x00A186E6+952038]
# 	GetHandleVerifier [0x00DF0CB2+2738370]
# 	GetHandleVerifier [0x00DE21B8+2678216]
# 	GetHandleVerifier [0x00BD17AA+512954]
# 	GetHandleVerifier [0x00BD0856+509030]
# 	Ordinal0 [0x00AE743B+1799227]
# 	Ordinal0 [0x00AEBB68+1817448]
# 	Ordinal0 [0x00AEBC55+1817685]
# 	Ordinal0 [0x00AF5230+1856048]
# 	BaseThreadInitThunk [0x759F6739+25]
# 	RtlGetFullPathName_UEx [0x771690AF+1215]
# 	RtlGetFullPathName_UEx [0x7716907D+1165]
